# %%
# %pip install folium
# Out:
# Collecting folium
#   Using cached folium-0.19.6-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from requests->folium) (2024.8.30)
# Using cached folium-0.19.6-py2.py3-none-any.whl (112 kB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: xyzservices, jinja2, branca, folium
# Successfully installed branca-0.8.1 folium-0.19.6 jinja2-3.1.6 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

target_dir = "C:/Users/asus/0528/STM_datasets/2025/"

for root, _, files in os.walk(target_dir):
    for file in files:
        if file == "TB_OPR_STATION.csv":
            file_path = os.path.join(root, file)
            try:
                with open(file_path, "r", encoding="cp949", errors="replace") as f:
                    lines = f.readlines()
            except Exception as e:
                print(f"❌ 파일 열기 실패: {file_path}, 사유: {e}")
                continue
            if not lines[-1].rstrip().endswith('"'):
                lines[-1] = lines[-1].rstrip("\r\n") + '"\n'
                try:
                    with open(file_path, "w", encoding="utf-8", errors="replace") as f:
                        f.writelines(lines)
                    print(f'✅ 마지막 줄에 " 추가 완료: {file_path}')
                except Exception as e:
                    print(f'❌ 파일 저장 실패: {file_path}, 사유: {e}')
            else:
                print(f'⭕ 이미 정상: {file_path}')
# Out:
# ⭕ 이미 정상: C:/Users/asus/0528/STM_datasets/2025/202501\250101\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250102\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250103\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250104\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250105\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250106\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250107\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250108\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250109\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250110\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250111\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250112\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250113\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250114\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250115\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250116\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250117\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250118\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250119\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250120\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250121\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250122\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250123\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250124\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250125\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250126\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250127\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250128\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250129\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250130\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202501\250131\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250201\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250202\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250203\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250204\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250205\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250206\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250207\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250208\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250209\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250210\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250211\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250212\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250213\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250214\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250215\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250216\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250217\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250218\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250219\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250220\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250221\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250222\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250223\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250224\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250225\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250226\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250227\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202502\250228\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250301\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250302\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250303\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250304\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250305\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250306\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250307\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250308\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250309\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250310\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250311\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250312\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250313\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250314\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250315\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250316\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250317\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250318\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250319\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250320\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250321\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250322\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250323\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250324\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250325\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250326\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250327\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250328\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250329\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250330\TB_OPR_STATION.csv
# ✅ 마지막 줄에 " 추가 완료: C:/Users/asus/0528/STM_datasets/2025/202503\250331\TB_OPR_STATION.csv

# %% [markdown]
# ##### utf-8 인코딩 변경

# %%
import os
import pandas as pd

# 변환할 최상위 폴더 경로 입력
base_dir = "C:/Users/asus/0528/STM_datasets/"

for root, _, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".csv"):
            file_path = os.path.join(root, file)
            try:
                # utf-8로 먼저 읽기
                df = pd.read_csv(file_path, encoding='utf-8', on_bad_lines='skip')
            except Exception as e1:
                try:
                    # 안 되면 cp949로 읽기
                    df = pd.read_csv(file_path, encoding='cp949', on_bad_lines='skip')
                except Exception as e2:
                    print(f"❌ 변환 실패: {file_path}, 사유: {e1}, {e2}")
                    continue
            try:
                # utf-8-sig로 **덮어쓰기**
                df.to_csv(file_path, index=False, encoding='utf-8-sig')
                print(f"✅ 덮어쓰기 변환 완료: {file_path}")
            except Exception as e:
                print(f"❌ 저장 실패: {file_path}, 사유: {e}")
# Out:
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TBIS_TPSS_merge.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240101\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TBIS_TPSS_merge.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240105\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\
.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240112\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TBIS_TPSS_merge.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240113\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TBIS_TPSS_merge.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240114\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240115\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240116\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\
.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240119\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240120\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240121\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240122\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\
.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240126\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240127\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240128\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240129\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240129\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2024\202401\240129\KSCC_DX_PATTERN_STAT.csv
# ...
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250323\TPSS_STA_ROUTE_INFO_H_TURN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250324\DISTRICT_EMD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250324\KSCC_DV_SUBWAY_STATION_GEOM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250324\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\
.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\KSCC_DX_PATTERN_STAT.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\KSCC_DX_RA_OD.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\KSCC_DX_TRIP_CHAIN_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\KSCC_DX_TRNSF_PATH_SUM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TBIS_MS_ROUTE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TBIS_MS_ROUTE_NODE.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TBIS_MS_STTN.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TB_OPR_STATION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_A18_ROUTE_SECTION.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_BCYCL_OD_STATN_HM.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_INFO_H_BUS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_INFO_H_PUBLIC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_INFO_H_SUBWAY.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_OD_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_OD_PS.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_EMD_OD_TC.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_ROUTE_SECTION_SPEED_H.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_STA_ROUTE_INFO_H_PASNGR.csv
# ✅ 덮어쓰기 변환 완료: C:/Users/asus/0528/STM_datasets/2025\202503\250331\TPSS_STA_ROUTE_INFO_H_TURN.csv

# %% [markdown]
# ##### STTN_ID 기준으로 병합

# %%
import os
import pandas as pd

base_dir = "C:/Users/asus/0528/STM_datasets/"

for year in os.listdir(base_dir):
    year_path = os.path.join(base_dir, year)
    if not os.path.isdir(year_path): continue
    for month in os.listdir(year_path):
        month_path = os.path.join(year_path, month)
        if not os.path.isdir(month_path): continue
        for day in os.listdir(month_path):
            day_path = os.path.join(month_path, day)
            if not os.path.isdir(day_path): continue

            sttn_path = os.path.join(day_path, "TBIS_MS_STTN.csv")
            cnt_path = os.path.join(day_path, "TPSS_STA_ROUTE_INFO_H_PASNGR.csv")
            output_path = os.path.join(day_path, "TBIS_TPSS_merge.csv")

            if os.path.isfile(sttn_path) and os.path.isfile(cnt_path):
                try:
                    # utf-8로 읽기 (안 되면 cp949로 fallback)
                    try:
                        loc_df = pd.read_csv(sttn_path, encoding='utf-8')
                    except Exception:
                        loc_df = pd.read_csv(sttn_path, encoding='cp949')
                    try:
                        cnt_df = pd.read_csv(cnt_path, encoding='utf-8')
                    except Exception:
                        cnt_df = pd.read_csv(cnt_path, encoding='cp949')

                    # 컬럼명 정규화
                    loc_df.columns = [c.upper().replace(" ", "").replace("-", "_") for c in loc_df.columns]
                    cnt_df.columns = [c.upper().replace(" ", "").replace("-", "_") for c in cnt_df.columns]

                    loc_cols = ['STTN_ID', 'STTN_NM', 'CRDNT_X', 'CRDNT_Y']
                    cnt_cols = ['STTN_ID', 'CNT']
                    if all(col in loc_df.columns for col in loc_cols) and all(col in cnt_df.columns for col in cnt_cols):
                        loc_df = loc_df[loc_cols]
                        cnt_df = cnt_df[cnt_cols]

                        # 병합 (STTN_ID 기준)
                        merged = pd.merge(loc_df, cnt_df, on='STTN_ID')
                        merged.dropna(subset=['CRDNT_X', 'CRDNT_Y', 'CNT'], inplace=True)
                        merged.to_csv(output_path, index=False, encoding='utf-8')
                        print(f"✅ [{day_path}] 병합 성공 (기준: STTN_ID, 행: {len(merged)})")
                    else:
                        print(f"⚠️ [{day_path}] 컬럼 부족 또는 불일치")
                except Exception as e:
                    print(f"❌ [{day_path}] 병합 실패: {e}")
            else:
                print(f"❌ [{day_path}] 위치 or 이용량 파일 없음")
# Out:
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240101] 병합 성공 (기준: STTN_ID, 행: 35701)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240105] 병합 성공 (기준: STTN_ID, 행: 37075)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240106] 병합 성공 (기준: STTN_ID, 행: 36292)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240107] 병합 성공 (기준: STTN_ID, 행: 35891)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240108] 병합 성공 (기준: STTN_ID, 행: 36913)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240109] 병합 성공 (기준: STTN_ID, 행: 37011)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240110] 병합 성공 (기준: STTN_ID, 행: 36976)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240111] 병합 성공 (기준: STTN_ID, 행: 36976)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240112] 병합 성공 (기준: STTN_ID, 행: 37062)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240113] 병합 성공 (기준: STTN_ID, 행: 36319)
# ✅ [C:/Users/asus/0528/STM_datasets/2024\202401\240114] 병합 성공 (기준: STTN_ID, 행: 35818)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 28
#      26     loc_df = pd.read_csv(sttn_path, encoding='cp949')
#      27 try:
# ---> 28     cnt_df = pd.read_csv(cnt_path, encoding='utf-8')
#      29 except Exception:
#      30     cnt_df = pd.read_csv(cnt_path, encoding='cp949')
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\internals\managers.py:2139, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2121 def create_block_manager_from_column_arrays(
#    2122     arrays: list[ArrayLike],
#    2123     axes: list[Index],
#    (...)
#    2135     # These last three are sufficient to allow us to safely pass
#    2136     #  verify_integrity=False below.
#    2138     try:
# -> 2139         blocks = _form_blocks(arrays, consolidate, refs)
#    2140         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2141     except ValueError as e:
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\internals\managers.py:2212, in _form_blocks(arrays, consolidate, refs)
#    2209 if issubclass(dtype.type, (str, bytes)):
#    2210     dtype = np.dtype(object)
# -> 2212 values, placement = _stack_arrays(list(tup_block), dtype)
#    2213 if is_dtlike:
#    2214     values = ensure_wrapped_if_datetimelike(values)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\core\internals\managers.py:2254, in _stack_arrays(tuples, dtype)
#    2252 stacked = np.empty(shape, dtype=dtype)
#    2253 for i, arr in enumerate(arrays):
# -> 2254     stacked[i] = arr
#    2256 return stacked, placement
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import folium

# === 설정 ===
# STM_datasets 경로 입력
base_dir = "C:/Users/asus/0528/STM_datasets/"

# years = ["2022", "2023", "2024", "2025"]
years = ["2024", "2025"]

# === 연도별 처리 ===
for year in years:
    year_path = os.path.join(base_dir, year)
    csv_files = []

    # 하위 폴더 탐색해서 CSV 수집
    for root, _, files in os.walk(year_path):
        for file in files:
            if file.endswith(".csv"):
                csv_files.append(os.path.join(root, file))

    print(f"[{year}] 총 {len(csv_files)}개 파일 수집됨")

    # 파일 읽어서 통합
    dfs = []
    for file in csv_files:
        try:
            df = pd.read_csv(file, encoding='utf-8', on_bad_lines='skip')
            # 필수 컬럼만 있는지 확인
            if {'STTN_ID', 'STTN_NM', 'CRDNT_X', 'CRDNT_Y', 'CNT'}.issubset(df.columns):
                dfs.append(df[['STTN_ID', 'STTN_NM', 'CRDNT_X', 'CRDNT_Y', 'CNT']])
        except Exception as e:
            print(f"읽기 실패: {file}, 이유: {e}")

    if not dfs:
        print(f"[{year}] 유효한 데이터 없음")
        continue

    merged = pd.concat(dfs, ignore_index=True)
    merged.dropna(subset=['CRDNT_X', 'CRDNT_Y', 'CNT'], inplace=True)

    # 정류장 단위 집계
    grouped = merged.groupby(['STTN_ID', 'STTN_NM', 'CRDNT_X', 'CRDNT_Y'])['CNT'].sum().reset_index()
    grouped = grouped.sort_values(by='CNT', ascending=False).head(300)

    # 지도 생성
    m = folium.Map(location=[37.5665, 126.9780], zoom_start=11)

    for _, row in grouped.iterrows():
        folium.CircleMarker(
            location=[row['CRDNT_Y'], row['CRDNT_X']],
            radius=max(row['CNT'] / 1000, 3),
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            popup=f"{row['STTN_NM']}<br>{int(row['CNT']):,}명"
        ).add_to(m)

    # 저장
    map_file = f"{year}_정류장_지도.html"
    m.save(map_file)
    print(f"[{year}] 시각화 저장 완료: {map_file}")
# Out:
# [2024] 총 1848개 파일 수집됨
# C:\Users\asus\AppData\Local\Temp\ipykernel_21812\1473807501.py:29: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, encoding='utf-8', on_bad_lines='skip')
# C:\Users\asus\AppData\Local\Temp\ipykernel_21812\1473807501.py:29: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, encoding='utf-8', on_bad_lines='skip')
# [2024] 유효한 데이터 없음
# [2025] 총 1890개 파일 수집됨
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250101\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250102\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250103\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250104\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250105\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250106\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250107\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250108\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250109\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# 읽기 실패: C:/Users/asus/0528/STM_datasets/2025\202501\250110\TB_OPR_STATION.csv, 이유: Error tokenizing data. C error: EOF inside string starting at row 756
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 29
#      27 for file in csv_files:
#      28     try:
# ---> 29         df = pd.read_csv(file, encoding='utf-8', on_bad_lines='skip')
#      30         # 필수 컬럼만 있는지 확인
#      31         if {'STTN_ID', 'STTN_NM', 'CRDNT_X', 'CRDNT_Y', 'CNT'}.issubset(df.columns):
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\asus\anaconda3\envs\dmu\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# KeyboardInterrupt:
